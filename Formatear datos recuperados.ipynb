# %% [markdown]
# ## Formatear datos recuperados

# %% [markdown]
# Empleamos cláusulas de SQL para formatear y editar el resultado de las consultas. También exportamos los resultados de las consultas formateadas a un archivo de texto para que pueda analizarlos en otros paquetes de software como Tableau o Excel. Usamos AS, DISTINCT y ORDER BY.

# %%
# %load_ext sql

# %%
# %sql mysql://studentuser:studentpw@localhost/dognitiondb

# %% [markdown]
# Se emplea AS para cambiar los títulos de las columnas en una salida, permite asignar un alias (un nombre temporal) a una tabla o una columna de una tabla y aumentar la legibilidad de las consultas.
# Necesitamos cambiar el nombre del campo de marca de tiempo de la tabla completed_tests de "created_at" a "time_stamp":

# %%
# %%sql
# SELECT dog_guid, created_at AS time_stamp
# FROM complete_tests AS tests
# LIMIT 4;

# %% [markdown]
# Necesitamos cambiar el título del campo "start_time" en la tabla exam_answers a "exam start time" en el resultado de la consulta. Tener en cuenta que un alias que incluye un espacio, debe estar entre comillas y MySQL admite comillas simples y dobles:

# %%
# %%sql
# SELECT start_time AS "exam start time"
# FROM exam_answers
# LIMIT 4;

# %% [markdown]
# Se usa la cláusula DISTINCT para eliminar filas duplicadas, dado que esta base de datos no se declararon claves principales en en las tablas, y a veces se pueden ingresar filas duplicadas completas por error.
# Supongamos que nos interesa saber cuáles son los diferentes valores posibles en la columna, necesitamos la lista de todas las razas de perros de la base de datos:

# %% [markdown]
# Cabe destacar que si se usa la cláusula DISTINCT en una columna que tiene valores NULL, MySQL incluirá un sólo valor NULL en la salida DISTINCT de esa columna.

# %%
# %%sql
# SELECT DISTINCT breed
# FROM dogs;

# %% [markdown]
# Cuando la cláusula DISTINCT se usa con varias columnas en una declaración SELECT, la combinación de todas las columnas juntas se usa para determinar la unicidad de una fila en un conjunto de resultados. Por ejemplo, si quisieramos conocer todas las combinaciones posibles de estados y ciudades en la tabla de usuarios.
# Observamos que, obtenemos muchas filas con California (CA) en la columna del estado y tres filas con Gainesville en la columna de la ciudad (Georgia, Florida y Virginia tienen ciudades llamadas Gainesville en nuestra tabla de usuarios), pero no hay dos filas que tengan la misma combinación de estado y ciudad.

# %%
# %%sql
# SELECT DISTINCT state, city
# FROM users;

# %%
# %%sql
# SELECT DISTINCT state, city
# FROM users
# WHERE state = "CA" AND city = "Gainesville";

# %%
# %%sql
# SELECT DISTINCT state, city
# FROM users
# WHERE state = "CA";

# %%
# %%sql
# SELECT DISTINCT state, city
# FROM users
# WHERE city = "Gainesville";

# %% [markdown]
# **Observación:** Cuando usa la cláusula DISTINCT con la cláusula LIMIT, MySQL deja de buscar cuando encuentra el número de filas únicas especificadas en la cláusula LIMIT, no cuando pasa por el número de filas en la cláusula LIMIT. Por ejemplo, recuperamos los estados de la base y limitamos la salida a las 8 primeras filas´usando SELECT y LIMIT. Podemos ver que sólo se repite un estado, es decir, tenemos 7 valores únicos en las 8 primeras filas. Después, agregamos la cláusula DISTINCT y mantemos limitada la salida en 8. Vemos que la búsqueda de valores distintos no se detiene en las primeras 8 filas sino cuando  encuentra los primeros 8 valores únicos.

# %%
# %%sql
# SELECT state
# FROM users
# LIMIT 8;

# %%
# %%sql
# SELECT DISTINCT state
# FROM users
# LIMIT 8;

# %% [markdown]
# El uso de la poderosa cláusula ORDER BY para permitirle ordenar la salida de acuerdo con nuestras propias especificaciones y de esta manera, clasificar los resultados de las salidas. Por ejemplo, deseamos que las razas de perros estén ordenadas alfabéticamente. Por defecto, el orden es un forma ascendente, pero podemos indicarle de qué forma necesitamos:

# %%
# %%sql
# SELECT DISTINCT breed
# FROM dogs
# ORDER BY breed;

# %%
# %%sql
# SELECT DISTINCT breed
# FROM dogs
# ORDER BY breed DESC;
# Out:
#  * mysql://studentuser:***@localhost/dognitiondb
# 2006 rows affected.
# [('Yorkshire Terrier-Soft Coated Wheaten Terrier Mix',),
#  ('Yorkshire Terrier-Silky Terrier Mix',),
#  ('Yorkshire Terrier-Shih Tzu Mix',),
#  ('Yorkshire Terrier-Rat Terrier Mix',),
#  ('Yorkshire Terrier-Poodle Mix',),
#  ('Yorkshire Terrier-Pomeranian Mix',),
#  ('Yorkshire Terrier-Pekingese Mix',),
#  ('Yorkshire Terrier-Miniature Schnauzer Mix',),
#  ('Yorkshire Terrier-Miniature Pinscher Mix',),
#  ('Yorkshire Terrier-Maltese Mix',),
#  ('Yorkshire Terrier-Lhasa Apso Mix',),
#  ('Yorkshire Terrier-Havanese Mix',),
#  ('Yorkshire Terrier-German Wirehaired Pointer Mix',),
#  ('Yorkshire Terrier-German Spitz Mix',),
#  ('Yorkshire Terrier-Dogue de Bordeaux Mix',),
#  ('Yorkshire Terrier-Chihuahua Mix',),
#  ('Yorkshire Terrier-Cairn Terrier Mix',),
#  ('Yorkshire Terrier-Bichon Frise Mix',),
#  ('Yorkshire Terrier-Belgian Malinois Mix',),
#  ('Yorkshire Terrier-Australian Terrier Mix',),
#  ('Yorkshire Terrier- Mix',),
#  ('Yorkshire Terrier',),
#  ('Xoloitzcuintli',),
#  ('Wirehaired Vizsla',),
#  ('Wirehaired Pointing Griffon',),
#  ('Wire Fox Terrier-Parson Russell Terrier Mix',),
#  ('Wire Fox Terrier-Lhasa Apso Mix',),
#  ('Wire Fox Terrier-Italian Greyhound Mix',),
#  ('Wire Fox Terrier-Dachshund Mix',),
#  ('Wire Fox Terrier-Chihuahua Mix',),
#  ('Wire Fox Terrier-Bulldog Mix',),
#  ('Wire Fox Terrier-Australian Cattle Dog Mix',),
#  ('Wire Fox Terrier',),
#  ('Whippet-Tibetan Terrier Mix',),
#  ('Whippet-Scottish Deerhound Mix',),
#  ('Whippet-Saluki Mix',),
#  ('Whippet-Russell Terrier Mix',),
#  ('Whippet-Rhodesian Ridgeback Mix',),
#  ('Whippet-Rat Terrier Mix',),
#  ('Whippet-Poodle Mix',),
#  ('Whippet-Pointer Mix',),
#  ('Whippet-Labrador Retriever Mix',),
#  ('Whippet-Italian Greyhound Mix',),
#  ('Whippet-Greyhound Mix',),
#  ('Whippet-German Shepherd Dog Mix',),
#  ('Whippet-Collie Mix',),
#  ('Whippet-Chinese Shar-Pei Mix',),
#  ('Whippet-Border Collie Mix',),
#  ('Whippet-Beagle Mix',),
#  ('Whippet-Basenji Mix',),
#  ('Whippet',),
#  ('West Highland White Terrier-Poodle Mix',),
#  ('West Highland White Terrier-Parson Russell Terrier Mix',),
#  ('West Highland White Terrier-Lhasa Apso Mix',),
#  ('West Highland White Terrier-Dachshund Mix',),
#  ('West Highland White Terrier-Border Terrier Mix',),
#  ('West Highland White Terrier-Bichon Frise Mix',),
#  ('West Highland White Terrier',),
#  ('Welsh Terrier-Miniature Schnauzer Mix',),
#  ('Welsh Terrier',),
#  ('Welsh Springer Spaniel-Nova Scotia Duck Tolling Retriever Mix',),
#  ('Welsh Springer Spaniel',),
#  ('Weimaraner-Labrador Retriever Mix',),
#  ('Weimaraner-Bluetick Coonhound Mix',),
#  ('Weimaraner-Beagle Mix',),
#  ('Weimaraner-American Pit Bull Terrier Mix',),
#  ('Weimaraner- Mix',),
#  ('Weimaraner',),
#  ('Vizsla-Rhodesian Ridgeback Mix',),
#  ('Vizsla-German Shorthaired Pointer Mix',),
#  ('Vizsla-Dachshund Mix',),
#  ('Vizsla-American Pit Bull Terrier Mix',),
#  ('Vizsla- Mix',),
#  ('Vizsla',),
#  ('Treeing Walker Coonhound-Pointer Mix',),
#  ('Treeing Walker Coonhound-Parson Russell Terrier Mix',),
#  ('Treeing Walker Coonhound-Labrador Retriever Mix',),
#  ('Treeing Walker Coonhound-Great Dane Mix',),
#  ('Treeing Walker Coonhound-English Foxhound Mix',),
#  ('Treeing Walker Coonhound-Beagle Mix',),
#  ('Treeing Walker Coonhound- Mix',),
#  ('Treeing Walker Coonhound',),
#  ('Treeing Tennessee Brindle-Plott Mix',),
#  ('Treeing Tennessee Brindle',),
#  ('Toy Fox Terrier-Yorkshire Terrier Mix',),
#  ('Toy Fox Terrier-Shih Tzu Mix',),
#  ('Toy Fox Terrier-German Shepherd Dog Mix',),
#  ('Toy Fox Terrier-Chihuahua Mix',),
#  ('Toy Fox Terrier-Australian Shepherd Mix',),
#  ('Toy Fox Terrier',),
#  ('Tosa- Mix',),
#  ('Tosa',),
#  ('Tibetan Terrier-Jack Russell Terrier Mix',),
#  ('Tibetan Terrier-Border Collie Mix',),
#  ('Tibetan Terrier',),
#  ('Tibetan Spaniel-Papillon Mix',),
#  ('Tibetan Spaniel-Chihuahua Mix',),
#  ('Tibetan Spaniel',),
#  ('Tibetan Mastiff',),
#  ('Thai Ridgeback-American Pit Bull Terrier Mix',),
#  ('Thai Ridgeback',),
#  ('Swedish Vallhund',),
#  ('Swedish Lapphund',),
#  ('Sussex Spaniel-English Cocker Spaniel Mix',),
#  ('Standard Schnauzer-Yorkshire Terrier Mix',),
#  ('Standard Schnauzer-Russell Terrier Mix',),
#  ('Standard Schnauzer-Poodle Mix',),
#  ('Standard Schnauzer-Miniature Schnauzer Mix',),
#  ('Standard Schnauzer-Doberman Pinscher Mix',),
#  ('Standard Schnauzer',),
#  ('Standard Poodle-Standard Schnauzer Mix',),
#  ('Standard Poodle-Soft Coated Wheaten Terrier Mix',),
#  ('Standard Poodle-Old English Sheepdog Mix',),
#  ('Standard Poodle-Labrador Retriever Mix',),
#  ('Standard Poodle-Irish Setter Mix',),
#  ('Standard Poodle-Golden Retriever Mix',),
#  ('Standard Poodle-German Shepherd Dog Mix',),
#  ('Standard Poodle-English Cocker Spaniel Mix',),
#  ('Standard Poodle-Dachshund Mix',),
#  ('Standard Poodle-Chinese Shar-Pei Mix',),
#  ('Standard Poodle',),
#  ('Staffordshire Bull Terrier-Whippet Mix',),
#  ('Staffordshire Bull Terrier-Russell Terrier Mix',),
#  ('Staffordshire Bull Terrier-Rottweiler Mix',),
#  ('Staffordshire Bull Terrier-Rhodesian Ridgeback Mix',),
#  ('Staffordshire Bull Terrier-Miniature Schnauzer Mix',),
#  ('Staffordshire Bull Terrier-Mastiff Mix',),
#  ('Staffordshire Bull Terrier-Labrador Retriever Mix',),
#  ('Staffordshire Bull Terrier-Great Dane Mix',),
#  ('Staffordshire Bull Terrier-Dachshund Mix',),
#  ('Staffordshire Bull Terrier-Bullmastiff Mix',),
#  ('Staffordshire Bull Terrier-Bulldog Mix',),
#  ('Staffordshire Bull Terrier-Bull Terrier Mix',),
#  ('Staffordshire Bull Terrier-Boxer Mix',),
#  ('Staffordshire Bull Terrier-Boston Terrier Mix',),
#  ('Staffordshire Bull Terrier-Border Collie Mix',),
#  ('Staffordshire Bull Terrier-Bernese Mountain Dog Mix',),
#  ('Staffordshire Bull Terrier-Beagle Mix',),
#  ('Staffordshire Bull Terrier-Australian Kelpie Mix',),
#  ('Staffordshire Bull Terrier-Australian Cattle Dog Mix',),
#  ('Staffordshire Bull Terrier-American Staffordshire Terrier Mix',),
#  ('Staffordshire Bull Terrier- Mix',),
#  ('Staffordshire Bull Terrier',),
#  ('Stabyhoun',),
#  ('St. Bernard-Standard Poodle Mix',),
#  ('St. Bernard-Rottweiler Mix',),
#  ('St. Bernard-Labrador Retriever Mix',),
#  ('St. Bernard-Greater Swiss Mountain Dog Mix',),
#  ('St. Bernard-Great Pyrenees Mix',),
#  ('St. Bernard-Dachshund Mix',),
#  ('St. Bernard-Caucasian Ovcharka Mix',),
#  ('St. Bernard-Brittany Mix',),
#  ('St. Bernard-Border Collie Mix',),
#  ('St. Bernard-Black and Tan Coonhound Mix',),
#  ('St. Bernard- Mix',),
#  ('St. Bernard',),
#  ('Spinone Italiano',),
#  ('Spanish Water Dog-Bichon Frise Mix',),
#  ('Spanish Water Dog',),
#  ('Spanish Mastiff',),
#  ('Soft Coated Wheaten Terrier-Poodle Mix',),
#  ('Soft Coated Wheaten Terrier-Papillon Mix',),
#  ('Soft Coated Wheaten Terrier-Labrador Retriever Mix',),
#  ('Soft Coated Wheaten Terrier',),
#  ('Smooth Fox Terrier-Whippet Mix',),
#  ('Smooth Fox Terrier-Rhodesian Ridgeback Mix',),
#  ('Smooth Fox Terrier-Collie Mix',),
#  ('Smooth Fox Terrier-Chihuahua Mix',),
#  ('Smooth Fox Terrier-Bluetick Coonhound Mix',),
#  ('Smooth Fox Terrier',),
#  ('Small Munsterlander Pointer',),
#  ('Sloughi-Greyhound Mix',),
#  ('Skye Terrier',),
#  ('Silky Terrier-Schipperke Mix',),
#  ('Silky Terrier-Poodle Mix',),
#  ('Silky Terrier-Lhasa Apso Mix',),
#  ('Silky Terrier-Chihuahua Mix',),
#  ('Silky Terrier-Basset Hound Mix',),
#  ('Silky Terrier',),
#  ('Siberian Husky-Vizsla Mix',),
#  ('Siberian Husky-Standard Schnauzer Mix',),
#  ('Siberian Husky-Staffordshire Bull Terrier Mix',),
#  ('Siberian Husky-St. Bernard Mix',),
#  ('Siberian Husky-Shiba Inu Mix',),
#  ('Siberian Husky-Samoyed Mix',),
#  ('Siberian Husky-Rottweiler Mix',),
#  ('Siberian Husky-Rhodesian Ridgeback Mix',),
#  ('Siberian Husky-Mastiff Mix',),
#  ('Siberian Husky-Labrador Retriever Mix',),
#  ('Siberian Husky-Keeshond Mix',),
#  ('Siberian Husky-Jack Russell Terrier Mix',),
#  ('Siberian Husky-Greyhound Mix',),
#  ('Siberian Husky-German Shorthaired Pointer Mix',),
#  ('Siberian Husky-German Shepherd Dog Mix',),
#  ('Siberian Husky-Chow Chow Mix',),
#  ('Siberian Husky-Boxer Mix',),
#  ('Siberian Husky-Border Collie Mix',),
#  ('Siberian Husky-Bloodhound Mix',),
#  ('Siberian Husky-Bernese Mountain Dog Mix',),
#  ('Siberian Husky-Belgian Malinois Mix',),
#  ('Siberian Husky-Beagle Mix',),
#  ('Siberian Husky-Australian Shepherd Mix',),
#  ('Siberian Husky-Australian Cattle Dog Mix',),
#  ('Siberian Husky-American Staffordshire Terrier Mix',),
#  ('Siberian Husky-American Pit Bull Terrier Mix',),
#  ('Siberian Husky-American Eskimo Dog Mix',),
#  ('Siberian Husky-American English Coonhound Mix',),
#  ('Siberian Husky-Alaskan Malamute Mix',),
#  ('Siberian Husky- Mix',),
#  ('Siberian Husky',),
#  ('Shorkie',),
#  ('Shih Tzu-Yorkshire Terrier Mix',),
#  ('Shih Tzu-Wire Fox Terrier Mix',),
#  ('Shih Tzu-West Highland White Terrier Mix',),
#  ('Shih Tzu-Silky Terrier Mix',),
#  ('Shih Tzu-Russell Terrier Mix',),
#  ('Shih Tzu-Pug Mix',),
#  ('Shih Tzu-Poodle Mix',),
#  ('Shih Tzu-Pomeranian Mix',),
#  ('Shih Tzu-Pekingese Mix',),
#  ('Shih Tzu-Maltese Mix',),
#  ('Shih Tzu-Lhasa Apso Mix',),
#  ('Shih Tzu-Jack Russell Terrier Mix',),
#  ('Shih Tzu-Havanese Mix',),
#  ('Shih Tzu-Dachshund Mix',),
#  ('Shih Tzu-Coton de Tulear Mix',),
#  ('Shih Tzu-Chihuahua Mix',),
#  ('Shih Tzu-Cavalier King Charles Spaniel Mix',),
#  ('Shih Tzu-Bull Terrier Mix',),
#  ('Shih Tzu-Brussels Griffon Mix',),
#  ('Shih Tzu-Border Collie Mix',),
#  ('Shih Tzu-Bichon Frise Mix',),
#  ('Shih Tzu- Mix',),
#  ('Shih Tzu',),
#  ('Shiba Inu-Pembroke Welsh Corgi Mix',),
#  ('Shiba Inu-Labrador Retriever Mix',),
#  ('Shiba Inu-Beagle Mix',),
#  ('Shiba Inu',),
#  ('Shetland Sheepdog-Norwich Terrier Mix',),
#  ('Shetland Sheepdog-Labrador Retriever Mix',),
#  ('Shetland Sheepdog-Collie Mix',),
#  ('Shetland Sheepdog-Cairn Terrier Mix',),
#  ('Shetland Sheepdog-Border Collie Mix',),
#  ('Shetland Sheepdog-Australian Shepherd Mix',),
#  ('Shetland Sheepdog-Australian Cattle Dog Mix',),
#  ('Shetland Sheepdog-American Eskimo Dog Mix',),
#  ('Shetland Sheepdog',),
#  ('Sealyham Terrier',),
#  ('Scottish Terrier-Shih Tzu Mix',),
#  ('Scottish Terrier-Dachshund Mix',),
#  ('Scottish Terrier',),
#  ('Scottish Deerhound-Saluki Mix',),
#  ('Scottish Deerhound',),
#  ('Schipperke',),
#  ('Schapendoes',),
#  ('Samoyed-Shetland Sheepdog Mix',),
#  ('Samoyed-Chow Chow Mix',),
#  ('Samoyed',),
#  ('Saluki-Greyhound Mix',),
#  ('Saluki',),
#  ('Russian Toy-Chihuahua Mix',),
#  ('Russian Toy',),
#  ('Russell Terrier-Yorkshire Terrier Mix',),
#  ('Russell Terrier-Wire Fox Terrier Mix',),
#  ('Russell Terrier-Toy Fox Terrier Mix',),
#  ('Russell Terrier-Shih Tzu Mix',),
#  ('Russell Terrier-Rat Terrier Mix',),
#  ('Russell Terrier-Pug Mix',),
#  ('Russell Terrier-Poodle Mix',),
#  ('Russell Terrier-Pomeranian Mix',),
#  ('Russell Terrier-Parson Russell Terrier Mix',),
#  ('Russell Terrier-Miniature Schnauzer Mix',),
#  ('Russell Terrier-Miniature Pinscher Mix',),
#  ('Russell Terrier-Manchester Terrier Mix',),
#  ('Russell Terrier-Japanese Chin Mix',),
#  ('Russell Terrier-Golden Retriever Mix',),
#  ('Russell Terrier-English Foxhound Mix',),
#  ('Russell Terrier-Dachshund Mix',),
#  ('Russell Terrier-Cocker Spaniel Mix',),
#  ('Russell Terrier-Chihuahua Mix',),
#  ('Russell Terrier-Beagle Mix',),
#  ('Russell Terrier-Basenji Mix',),
#  ('Russell Terrier-Australian Cattle Dog Mix',),
#  ('Russell Terrier- Mix',),
#  ('Russell Terrier',),
#  ('Rottweiler-Staffordshire Bull Terrier Mix',),
#  ('Rottweiler-St. Bernard Mix',),
#  ('Rottweiler-Siberian Husky Mix',),
#  ('Rottweiler-Rhodesian Ridgeback Mix',),
#  ('Rottweiler-Redbone Coonhound Mix',),
#  ('Rottweiler-Miniature Pinscher Mix',),
#  ('Rottweiler-Mastiff Mix',),
#  ('Rottweiler-Labrador Retriever Mix',),
#  ('Rottweiler-Komondor Mix',),
#  ('Rottweiler-Greater Swiss Mountain Dog Mix',),
#  ('Rottweiler-German Shepherd Dog Mix',),
#  ('Rottweiler-Doberman Pinscher Mix',),
#  ('Rottweiler-Collie Mix',),
#  ('Rottweiler-Chow Chow Mix',),
#  ('Rottweiler-Bulldog Mix',),
#  ('Rottweiler-Boxer Mix',),
#  ('Rottweiler-Border Collie Mix',),
#  ('Rottweiler-Beagle Mix',),
#  ('Rottweiler-Australian Cattle Dog Mix',),
#  ('Rottweiler-American Pit Bull Terrier Mix',),
#  ('Rottweiler-American English Coonhound Mix',),
#  ('Rottweiler- Mix',),
#  ('Rottweiler',),
#  ('Rhodesian Ridgeback-Weimaraner Mix',),
#  ('Rhodesian Ridgeback-Vizsla Mix',),
#  ('Rhodesian Ridgeback-Redbone Coonhound Mix',),
#  ('Rhodesian Ridgeback-Mastiff Mix',),
#  ('Rhodesian Ridgeback-Labrador Retriever Mix',),
#  ('Rhodesian Ridgeback-Great Dane Mix',),
#  ('Rhodesian Ridgeback-German Shepherd Dog Mix',),
#  ('Rhodesian Ridgeback-English Springer Spaniel Mix',),
#  ('Rhodesian Ridgeback-Doberman Pinscher Mix',),
#  ('Rhodesian Ridgeback-Catahoula Leopard Dog Mix',),
#  ('Rhodesian Ridgeback-Boxer Mix',),
#  ('Rhodesian Ridgeback-Boston Terrier Mix',),
#  ('Rhodesian Ridgeback-American Water Spaniel Mix',),
#  ('Rhodesian Ridgeback-American Staffordshire Terrier Mix',),
#  ('Rhodesian Ridgeback-American Pit Bull Terrier Mix',),
#  ('Rhodesian Ridgeback',),
#  ('Redbone Coonhound-Vizsla Mix',),
#  ('Redbone Coonhound-Rhodesian Ridgeback Mix',),
#  ('Redbone Coonhound-Labrador Retriever Mix',),
#  ('Redbone Coonhound-German Shepherd Dog Mix',),
#  ('Redbone Coonhound-Bloodhound Mix',),
#  ('Redbone Coonhound-Basset Hound Mix',),
#  ('Redbone Coonhound-Australian Shepherd Mix',),
#  ('Redbone Coonhound',),
#  ('Rat Terrier-Yorkshire Terrier Mix',),
#  ('Rat Terrier-Schipperke Mix',),
#  ('Rat Terrier-Russell Terrier Mix',),
#  ('Rat Terrier-Parson Russell Terrier Mix',),
#  ('Rat Terrier-Papillon Mix',),
#  ('Rat Terrier-Miniature Pinscher Mix',),
#  ('Rat Terrier-Maltese Mix',),
#  ('Rat Terrier-Lancashire Heeler Mix',),
#  ('Rat Terrier-Italian Greyhound Mix',),
#  ('Rat Terrier-Dachshund Mix',),
#  ('Rat Terrier-Chinese Shar-Pei Mix',),
#  ('Rat Terrier-Chihuahua Mix',),
#  ('Rat Terrier-Cavalier King Charles Spaniel Mix',),
#  ('Rat Terrier-Catahoula Leopard Dog Mix',),
#  ('Rat Terrier-Cardigan Welsh Corgi Mix',),
#  ('Rat Terrier-Beagle Mix',),
#  ('Rat Terrier-Basenji Mix',),
#  ('Rat Terrier-Australian Cattle Dog Mix',),
#  ('Rat Terrier- Mix',),
#  ('Rat Terrier',),
#  ('Pyrenean Shepherd-Collie Mix',),
#  ('Pyrenean Shepherd',),
#  ('Pumi',),
#  ('Puli',),
#  ('Puggle',),
#  ('Pug-Wire Fox Terrier Mix',),
#  ('Pug-Smooth Fox Terrier Mix',),
#  ('Pug-Shih Tzu Mix',),
#  ('Pug-Russell Terrier Mix',),
#  ('Pug-Poodle Mix',),
#  ('Pug-Pomeranian Mix',),
#  ('Pug-Pekingese Mix',),
#  ('Pug-Miniature Pinscher Mix',),
#  ('Pug-Maltese Mix',),
#  ('Pug-Lhasa Apso Mix',),
#  ('Pug-Jack Russell Terrier Mix',),
#  ('Pug-French Bulldog Mix',),
#  ('Pug-Cocker Spaniel Mix',),
#  ('Pug-Chinese Shar-Pei Mix',),
#  ('Pug-Chihuahua Mix',),
#  ('Pug-Cavalier King Charles Spaniel Mix',),
#  ('Pug-Brussels Griffon Mix',),
#  ('Pug-Boston Terrier Mix',),
#  ('Pug-Beagle Mix',),
#  ('Pug-American Pit Bull Terrier Mix',),
#  ('Pug- Mix',),
#  ('Pug',),
#  ('Portuguese Water Dog',),
#  ('Portuguese Sheepdog',),
#  ('Portuguese Pointer',),
#  ('Portuguese Podengo-Greyhound Mix',),
#  ('Portuguese Podengo Pequeno-Jack Russell Terrier Mix',),
#  ('Portuguese Podengo Pequeno',),
#  ('Portuguese Podengo',),
#  ('Poodle-Yorkshire Terrier Mix',),
#  ('Poodle-West Highland White Terrier Mix',),
#  ('Poodle-Welsh Terrier Mix',),
#  ('Poodle-Weimaraner Mix',),
#  ('Poodle-Tibetan Terrier Mix',),
#  ('Poodle-Standard Schnauzer Mix',),
#  ('Poodle-Standard Poodle Mix',),
#  ('Poodle-Soft Coated Wheaten Terrier Mix',),
#  ('Poodle-Shih Tzu Mix',),
#  ('Poodle-Scottish Terrier Mix',),
#  ('Poodle-Russell Terrier Mix',),
#  ('Poodle-Redbone Coonhound Mix',),
#  ('Poodle-Rat Terrier Mix',),
#  ('Poodle-Pomeranian Mix',),
#  ('Poodle-Pekingese Mix',),
#  ('Poodle-Papillon Mix',),
#  ('Poodle-Old English Sheepdog Mix',),
#  ('Poodle-Newfoundland Mix',),
#  ('Poodle-Miniature Schnauzer Mix',),
#  ('Poodle-Maltese Mix',),
#  ('Poodle-Lowchen Mix',),
#  ('Poodle-Lhasa Apso Mix',),
#  ('Poodle-Labrador Retriever Mix',),
#  ('Poodle-Japanese Chin Mix',),
#  ('Poodle-Havanese Mix',),
#  ('Poodle-Golden Retriever Mix',),
#  ('Poodle-Giant Schnauzer Mix',),
#  ('Poodle-German Wirehaired Pointer Mix',),
#  ('Poodle-German Spitz Mix',),
#  ('Poodle-German Shepherd Dog Mix',),
#  ('Poodle-English Toy Spaniel Mix',),
#  ('Poodle-English Springer Spaniel Mix',),
#  ('Poodle-English Cocker Spaniel Mix',),
#  ('Poodle-Doberman Pinscher Mix',),
#  ('Poodle-Dachshund Mix',),
#  ('Poodle-Cocker Spaniel Mix',),
#  ('Poodle-Chinese Crested Mix',),
#  ('Poodle-Chihuahua Mix',),
#  ('Poodle-Cavalier King Charles Spaniel Mix',),
#  ('Poodle-Catahoula Leopard Dog Mix',),
#  ('Poodle-Border Collie Mix',),
#  ('Poodle-Bichon Frise Mix',),
#  ('Poodle-Bernese Mountain Dog Mix',),
#  ('Poodle-Beagle Mix',),
#  ('Poodle-Australian Shepherd Mix',),
#  ('Poodle-Australian Labradoodle Mix',),
#  ('Poodle-Australian Cattle Dog Mix',),
#  ('Poodle-American Pit Bull Terrier Mix',),
#  ('Poodle- Mix',),
#  ('Poodle',),
#  ('Pomeranian-Yorkshire Terrier Mix',),
#  ('Pomeranian-Toy Fox Terrier Mix',),
#  ('Pomeranian-Tibetan Spaniel Mix',),
#  ('Pomeranian-Siberian Husky Mix',),
#  ('Pomeranian-Shih Tzu Mix',),
#  ('Pomeranian-Shetland Sheepdog Mix',),
#  ('Pomeranian-Rat Terrier Mix',),
#  ('Pomeranian-Poodle Mix',),
#  ('Pomeranian-Pekingese Mix',),
#  ('Pomeranian-Papillon Mix',),
#  ('Pomeranian-Maltese Mix',),
#  ('Pomeranian-Dachshund Mix',),
#  ('Pomeranian-Chihuahua Mix',),
#  ('Pomeranian-Boston Terrier Mix',),
#  ('Pomeranian-Basenji Mix',),
#  ('Pomeranian-Australian Shepherd Mix',),
#  ('Pomeranian-Anatolian Shepherd Dog Mix',),
#  ('Pomeranian-American Eskimo Dog Mix',),
#  ('Pomeranian',),
#  ('Pomapoo',),
#  ('Polish Lowland Sheepdog',),
#  ('Pointer-Rhodesian Ridgeback Mix',),
#  ('Pointer-Parson Russell Terrier Mix',),
#  ('Pointer-Labrador Retriever Mix',),
#  ('Pointer-Bracco Italiano Mix',),
#  ('Pointer-Border Collie Mix',),
#  ('Pointer-Beagle Mix',),
#  ('Pointer-Australian Shepherd Mix',),
#  ('Pointer-American English Coonhound Mix',),
#  ('Pointer',),
#  ('Plott-Whippet Mix',),
#  ('Plott-Treeing Walker Coonhound Mix',),
#  ('Plott-Labrador Retriever Mix',),
#  ('Plott-German Shepherd Dog Mix',),
#  ('Plott-Boxer Mix',),
#  ('Plott-Border Collie Mix',),
#  ('Plott-Beagle Mix',),
#  ('Plott-American Pit Bull Terrier Mix',),
#  ('Plott-American Foxhound Mix',),
#  ('Plott',),
#  ('Pharaoh Hound-Australian Cattle Dog Mix',),
#  ('Pharaoh Hound',),
#  ('Petit Basset Griffon Vendeen',),
#  ('Peruvian Inca Orchid',),
#  ('Perro de Presa Canario-Rottweiler Mix',),
#  ('Perro de Presa Canario',),
#  ('Pembroke Welsh Corgi-Russell Terrier Mix',),
#  ('Pembroke Welsh Corgi-Rat Terrier Mix',),
#  ('Pembroke Welsh Corgi-Great Pyrenees Mix',),
#  ('Pembroke Welsh Corgi-Dachshund Mix',),
#  ('Pembroke Welsh Corgi-Chihuahua Mix',),
#  ('Pembroke Welsh Corgi-Border Collie Mix',),
#  ('Pembroke Welsh Corgi-Basset Hound Mix',),
#  ('Pembroke Welsh Corgi-Australian Shepherd Mix',),
#  ('Pembroke Welsh Corgi-Australian Cattle Dog Mix',),
#  ('Pembroke Welsh Corgi-American Eskimo Dog Mix',),
#  ('Pembroke Welsh Corgi',),
#  ('Pekingese-Tibetan Spaniel Mix',),
#  ('Pekingese-Shih Tzu Mix',),
#  ('Pekingese-Pug Mix',),
#  ('Pekingese-Poodle Mix',),
#  ('Pekingese-Pomeranian Mix',),
#  ('Pekingese-Pembroke Welsh Corgi Mix',),
#  ('Pekingese-Parson Russell Terrier Mix',),
#  ('Pekingese-Lhasa Apso Mix',),
#  ('Pekingese-Dachshund Mix',),
#  ('Pekingese-Cocker Spaniel Mix',),
#  ('Pekingese-Chihuahua Mix',),
#  ('Pekingese',),
#  ('Parson Russell Terrier-Russell Terrier Mix',),
#  ('Parson Russell Terrier-Rat Terrier Mix',),
#  ('Parson Russell Terrier-Poodle Mix',),
#  ('Parson Russell Terrier-Maltese Mix',),
#  ('Parson Russell Terrier-Jack Russell Terrier Mix',),
#  ('Parson Russell Terrier-Chihuahua Mix',),
#  ('Parson Russell Terrier-Cairn Terrier Mix',),
#  ('Parson Russell Terrier-Border Collie Mix',),
#  ('Parson Russell Terrier-Beagle Mix',),
#  ('Parson Russell Terrier- Mix',),
#  ('Parson Russell Terrier',),
#  ('Papillon-Pug Mix',),
#  ('Papillon-Poodle Mix',),
#  ('Papillon-Pomeranian Mix',),
#  ('Papillon-Miniature Schnauzer Mix',),
#  ('Papillon-Maltese Mix',),
#  ('Papillon-Japanese Chin Mix',),
#  ('Papillon-German Spitz Mix',),
#  ('Papillon-English Springer Spaniel Mix',),
#  ('Papillon-Chihuahua Mix',),
#  ('Papillon-Cavalier King Charles Spaniel Mix',),
#  ('Papillon-American Eskimo Dog Mix',),
#  ('Papillon',),
#  ('Otterhound',),
#  ('Other',),
#  ('Old English Sheepdog-Standard Poodle Mix',),
#  ('Old English Sheepdog-Poodle Mix',),
#  ('Old English Sheepdog-Labrador Retriever Mix',),
#  ('Old English Sheepdog-German Shepherd Dog Mix',),
#  ('Old English Sheepdog',),
#  ('Nova Scotia Duck Tolling Retriever-Chihuahua Mix',),
#  ('Nova Scotia Duck Tolling Retriever-Border Collie Mix',),
#  ('Nova Scotia Duck Tolling Retriever- Mix',),
#  ('Nova Scotia Duck Tolling Retriever',),
#  ('Norwich Terrier- Mix',),
#  ('Norwich Terrier',),
#  ('Norwegian Elkhound',),
#  ('Norwegian Buhund',),
#  ('Norfolk Terrier-Russell Terrier Mix',),
#  ('Norfolk Terrier-Norwich Terrier Mix',),
#  ('Norfolk Terrier',),
#  ('Newfoundland-Weimaraner Mix',),
#  ('Newfoundland-Standard Poodle Mix',),
#  ('Newfoundland-St. Bernard Mix',),
#  ('Newfoundland-Siberian Husky Mix',),
#  ('Newfoundland-Rottweiler Mix',),
#  ('Newfoundland-Poodle Mix',),
#  ('Newfoundland-Labrador Retriever Mix',),
#  ('Newfoundland-Great Pyrenees Mix',),
#  ('Newfoundland-Bergamasco Mix',),
#  ('Newfoundland',),
#  ('Neapolitan Mastiff-Boxer Mix',),
#  ('Neapolitan Mastiff',),
#  ('Mudi-Australian Cattle Dog Mix',),
#  ('Mudi',),
#  ('Mixed',),
#  ('Miniature Schnauzer-Yorkshire Terrier Mix',),
#  ('Miniature Schnauzer-Wire Fox Terrier Mix',),
#  ('Miniature Schnauzer-West Highland White Terrier Mix',),
#  ('Miniature Schnauzer-Standard Schnauzer Mix',),
#  ('Miniature Schnauzer-Soft Coated Wheaten Terrier Mix',),
#  ('Miniature Schnauzer-Shih Tzu Mix',),
#  ('Miniature Schnauzer-Scottish Terrier Mix',),
#  ('Miniature Schnauzer-Russell Terrier Mix',),
#  ('Miniature Schnauzer-Poodle Mix',),
#  ('Miniature Schnauzer-Miniature Pinscher Mix',),
#  ('Miniature Schnauzer-Miniature Australian Shepherd Mix',),
#  ('Miniature Schnauzer-Maltese Mix',),
#  ('Miniature Schnauzer-Labrador Retriever Mix',),
#  ('Miniature Schnauzer-Havanese Mix',),
#  ('Miniature Schnauzer-Cocker Spaniel Mix',),
#  ('Miniature Schnauzer-Chihuahua Mix',),
#  ('Miniature Schnauzer-Cairn Terrier Mix',),
#  ('Miniature Schnauzer-Brussels Griffon Mix',),
#  ('Miniature Schnauzer-Brittany Mix',),
#  ('Miniature Schnauzer-Australian Cattle Dog Mix',),
#  ('Miniature Schnauzer-Airedale Terrier Mix',),
#  ('Miniature Schnauzer- Mix',),
#  ('Miniature Schnauzer',),
#  ('Miniature Pinscher-Shih Tzu Mix',),
#  ('Miniature Pinscher-Russell Terrier Mix',),
#  ('Miniature Pinscher-Rat Terrier Mix',),
#  ('Miniature Pinscher-Poodle Mix',),
#  ('Miniature Pinscher-Pomeranian Mix',),
#  ('Miniature Pinscher-German Shepherd Dog Mix',),
#  ('Miniature Pinscher-Dachshund Mix',),
#  ('Miniature Pinscher-Chihuahua Mix',),
#  ('Miniature Pinscher-Border Collie Mix',),
#  ('Miniature Pinscher-Basenji Mix',),
#  ('Miniature Pinscher- Mix',),
#  ('Miniature Pinscher',),
#  ('Miniature Bull Terrier',),
#  ('Miniature Australian Shepherd-Shetland Sheepdog Mix',),
#  ('Miniature Australian Shepherd-Poodle Mix',),
#  ('Miniature Australian Shepherd',),
#  ('Miniature American Shepherd',),
#  ('Mastiff-St. Bernard Mix',),
#  ('Mastiff-Rottweiler Mix',),
#  ('Mastiff-Labrador Retriever Mix',),
#  ('Mastiff-Great Pyrenees Mix',),
#  ('Mastiff-Great Dane Mix',),
#  ('Mastiff-Flat-Coated Retriever Mix',),
#  ('Mastiff-Bulldog Mix',),
#  ('Mastiff-American Staffordshire Terrier Mix',),
#  ('Mastiff-American Pit Bull Terrier Mix',),
#  ('Mastiff',),
#  ('Mastador',),
#  ('Manchester Terrier-Labrador Retriever Mix',),
#  ('Manchester Terrier-Chihuahua Mix',),
#  ('Manchester Terrier',),
#  ('Maltese-Yorkshire Terrier Mix',),
#  ('Maltese-Wire Fox Terrier Mix',),
#  ('Maltese-West Highland White Terrier Mix',),
#  ('Maltese-Tibetan Spaniel Mix',),
#  ('Maltese-Standard Schnauzer Mix',),
#  ('Maltese-Standard Poodle Mix',),
#  ('Maltese-Silky Terrier Mix',),
#  ('Maltese-Shih Tzu Mix',),
#  ('Maltese-Poodle Mix',),
#  ('Maltese-Pomeranian Mix',),
#  ('Maltese-Pekingese Mix',),
#  ('Maltese-Papillon Mix',),
#  ('Maltese-Miniature Schnauzer Mix',),
#  ('Maltese-Lhasa Apso Mix',),
#  ('Maltese-Japanese Chin Mix',),
#  ('Maltese-Jack Russell Terrier Mix',),
#  ('Maltese-Havanese Mix',),
#  ('Maltese-Cocker Spaniel Mix',),
#  ('Maltese-Chihuahua Mix',),
#  ('Maltese-Cavalier King Charles Spaniel Mix',),
#  ('Maltese-Bichon Frise Mix',),
#  ('Maltese-American Foxhound Mix',),
#  ('Maltese- Mix',),
#  ('Maltese',),
#  ('Lowchen',),
#  ('Lhasa Apso-Yorkshire Terrier Mix',),
#  ('Lhasa Apso-Tibetan Spaniel Mix',),
#  ('Lhasa Apso-Shih Tzu Mix',),
#  ('Lhasa Apso-Poodle Mix',),
#  ('Lhasa Apso-Pekingese Mix',),
#  ('Lhasa Apso-Maltese Mix',),
#  ('Lhasa Apso-Keeshond Mix',),
#  ('Lhasa Apso-German Shepherd Dog Mix',),
#  ('Lhasa Apso-Dandie Dinmont Terrier Mix',),
#  ('Lhasa Apso-Dachshund Mix',),
#  ('Lhasa Apso-Cocker Spaniel Mix',),
#  ('Lhasa Apso-Bichon Frise Mix',),
#  ('Lhasa Apso-Basset Hound Mix',),
#  ('Lhasa Apso- Mix',),
#  ('Lhasa Apso',),
#  ('Leonberger-German Shepherd Dog Mix',),
#  ('Leonberger',),
#  ('Lancashire Heeler-Australian Cattle Dog Mix',),
#  ('Lancashire Heeler',),
#  ('Lakeland Terrier',),
#  ('Lagotto Romagnolo-Schapendoes Mix',),
#  ('Lagotto Romagnolo-Berger Picard Mix',),
#  ('Lagotto Romagnolo',),
#  ('Labrador Retriever-Whippet Mix',),
#  ('Labrador Retriever-Welsh Springer Spaniel Mix',),
#  ('Labrador Retriever-Weimaraner Mix',),
#  ('Labrador Retriever-Vizsla Mix',),
#  ('Labrador Retriever-Treeing Walker Coonhound Mix',),
#  ('Labrador Retriever-Standard Poodle Mix',),
#  ('Labrador Retriever-Staffordshire Bull Terrier Mix',),
#  ('Labrador Retriever-Stabyhoun Mix',),
#  ('Labrador Retriever-St. Bernard Mix',),
#  ('Labrador Retriever-Siberian Husky Mix',),
#  ('Labrador Retriever-Russell Terrier Mix',),
#  ('Labrador Retriever-Rottweiler Mix',),
#  ('Labrador Retriever-Rhodesian Ridgeback Mix',),
#  ('Labrador Retriever-Poodle Mix',),
#  ('Labrador Retriever-Pomeranian Mix',),
#  ('Labrador Retriever-Pointer Mix',),
#  ('Labrador Retriever-Plott Mix',),
#  ('Labrador Retriever-Pembroke Welsh Corgi Mix',),
#  ('Labrador Retriever-Norwegian Elkhound Mix',),
#  ('Labrador Retriever-Newfoundland Mix',),
#  ('Labrador Retriever-Neapolitan Mastiff Mix',),
#  ('Labrador Retriever-Mastiff Mix',),
#  ('Labrador Retriever-Jack Russell Terrier Mix',),
#  ('Labrador Retriever-Irish Red and White Setter Mix',),
#  ('Labrador Retriever-Greyhound Mix',),
#  ('Labrador Retriever-Great Pyrenees Mix',),
#  ('Labrador Retriever-Great Dane Mix',),
#  ('Labrador Retriever-Golden Retriever Mix',),
#  ('Labrador Retriever-German Shorthaired Pointer Mix',),
#  ('Labrador Retriever-German Shepherd Dog Mix',),
#  ('Labrador Retriever-Flat-Coated Retriever Mix',),
#  ('Labrador Retriever-Field Spaniel Mix',),
#  ('Labrador Retriever-English Springer Spaniel Mix',),
#  ('Labrador Retriever-English Foxhound Mix',),
#  ('Labrador Retriever-English Cocker Spaniel Mix',),
#  ('Labrador Retriever-Doberman Pinscher Mix',),
#  ('Labrador Retriever-Dalmatian Mix',),
#  ('Labrador Retriever-Dachshund Mix',),
#  ('Labrador Retriever-Collie Mix',),
#  ('Labrador Retriever-Cocker Spaniel Mix',),
#  ('Labrador Retriever-Chow Chow Mix',),
#  ('Labrador Retriever-Chinese Shar-Pei Mix',),
#  ('Labrador Retriever-Chesapeake Bay Retriever Mix',),
#  ('Labrador Retriever-Catahoula Leopard Dog Mix',),
#  ('Labrador Retriever-Cardigan Welsh Corgi Mix',),
#  ('Labrador Retriever-Cane Corso Mix',),
#  ('Labrador Retriever-Bullmastiff Mix',),
#  ('Labrador Retriever-Bulldog Mix',),
#  ('Labrador Retriever-Bull Terrier Mix',),
#  ('Labrador Retriever-Boykin Spaniel Mix',),
#  ('Labrador Retriever-Boxer Mix',),
#  ('Labrador Retriever-Border Collie Mix',),
#  ('Labrador Retriever-Bluetick Coonhound Mix',),
#  ('Labrador Retriever-Bloodhound Mix',),
#  ('Labrador Retriever-Black and Tan Coonhound Mix',),
#  ('Labrador Retriever-Bichon Frise Mix',),
#  ('Labrador Retriever-Belgian Malinois Mix',),
#  ('Labrador Retriever-Beauceron Mix',),
#  ('Labrador Retriever-Beagle Mix',),
#  ('Labrador Retriever-Basset Hound Mix',),
#  ('Labrador Retriever-Basenji Mix',),
#  ('Labrador Retriever-Australian Shepherd Mix',),
#  ('Labrador Retriever-Australian Cattle Dog Mix',),
#  ('Labrador Retriever-American Staffordshire Terrier Mix',),
#  ('Labrador Retriever-American Pit Bull Terrier Mix',),
#  ('Labrador Retriever-American Foxhound Mix',),
#  ('Labrador Retriever-American English Coonhound Mix',),
#  ('Labrador Retriever-Akita Mix',),
#  ('Labrador Retriever-Airedale Terrier Mix',),
#  ('Labrador Retriever-Afghan Hound Mix',),
#  ('Labrador Retriever- Mix',),
#  ('Labrador Retriever',),
#  ('Labradoodle',),
#  ('Kuvasz',),
#  ('Kooikerhondje',),
#  ('Komondor',),
#  ('Kerry Blue Terrier',),
#  ('Keeshond-Weimaraner Mix',),
#  ('Keeshond-Lhasa Apso Mix',),
#  ('Keeshond-German Shepherd Dog Mix',),
#  ('Keeshond-Chow Chow Mix',),
#  ('Keeshond-Chinese Shar-Pei Mix',),
#  ('Keeshond-American Eskimo Dog Mix',),
#  ('Keeshond',),
#  ('Karelian Bear Dog-Border Collie Mix',),
#  ('Karelian Bear Dog',),
#  ('Kai Ken',),
#  ('Jindo-Shiba Inu Mix',),
#  ('Jindo-Great Dane Mix',),
#  ('Jindo-German Shepherd Dog Mix',),
#  ('Jindo',),
#  ('Japanese Chin-Pekingese Mix',),
#  ('Japanese Chin-Papillon Mix',),
#  ('Japanese Chin-Maltese Mix',),
#  ('Japanese Chin-Italian Greyhound Mix',),
#  ('Japanese Chin',),
#  ('Jack-A-Poo',),
#  ('Jack Russell Terrier-Whippet Mix',),
#  ('Jack Russell Terrier-West Highland White Terrier Mix',),
#  ('Jack Russell Terrier-Welsh Terrier Mix',),
#  ('Jack Russell Terrier-Toy Fox Terrier Mix',),
#  ('Jack Russell Terrier-Staffordshire Bull Terrier Mix',),
#  ('Jack Russell Terrier-Smooth Fox Terrier Mix',),
#  ('Jack Russell Terrier-Siberian Husky Mix',),
#  ('Jack Russell Terrier-Shih Tzu Mix',),
#  ('Jack Russell Terrier-Rat Terrier Mix',),
#  ('Jack Russell Terrier-Pug Mix',),
#  ('Jack Russell Terrier-Poodle Mix',),
#  ('Jack Russell Terrier-Parson Russell Terrier Mix',),
#  ('Jack Russell Terrier-Miniature Schnauzer Mix',),
#  ('Jack Russell Terrier-Manchester Terrier Mix',),
#  ('Jack Russell Terrier-Maltese Mix',),
#  ('Jack Russell Terrier-Labrador Retriever Mix',),
#  ('Jack Russell Terrier-German Shepherd Dog Mix',),
#  ('Jack Russell Terrier-Doberman Pinscher Mix',),
#  ('Jack Russell Terrier-Dachshund Mix',),
#  ('Jack Russell Terrier-Chihuahua Mix',),
#  ('Jack Russell Terrier-Cavalier King Charles Spaniel Mix',),
#  ('Jack Russell Terrier-Boston Terrier Mix',),
#  ('Jack Russell Terrier-Border Collie Mix',),
#  ('Jack Russell Terrier-Beagle Mix',),
#  ('Jack Russell Terrier-Australian Cattle Dog Mix',),
#  ('Jack Russell Terrier-American Pit Bull Terrier Mix',),
#  ('Jack Russell Terrier',),
#  ('Italian Greyhound-Russell Terrier Mix',),
#  ('Italian Greyhound-Rat Terrier Mix',),
#  ('Italian Greyhound-Pug Mix',),
#  ('Italian Greyhound-Norwegian Lundehund Mix',),
#  ('Italian Greyhound-Miniature Pinscher Mix',),
#  ('Italian Greyhound-Dachshund Mix',),
#  ('Italian Greyhound-Chihuahua Mix',),
#  ('Italian Greyhound-Cardigan Welsh Corgi Mix',),
#  ('Italian Greyhound',),
#  ('Irish Wolfhound-Scottish Deerhound Mix',),
#  ('Irish Wolfhound-Mastiff Mix',),
#  ('Irish Wolfhound-Great Dane Mix',),
#  ('Irish Wolfhound-Bouvier des Flandres Mix',),
#  ('Irish Wolfhound',),
#  ('Irish Water Spaniel',),
#  ('Irish Terrier-Soft Coated Wheaten Terrier Mix',),
#  ('Irish Terrier-Gordon Setter Mix',),
#  ('Irish Terrier',),
#  ('Irish Setter-Poodle Mix',),
#  ('Irish Setter-Labrador Retriever Mix',),
#  ('Irish Setter-Border Collie Mix',),
#  ('Irish Setter',),
#  ('Irish Red and White Setter',),
#  ('Icelandic Sheepdog-Papillon Mix',),
#  ('Icelandic Sheepdog-Keeshond Mix',),
#  ('Icelandic Sheepdog',),
#  ('Ibizan Hound-Greyhound Mix',),
#  ('Ibizan Hound',),
#  ("I Don't Know",),
#  ('Hovawart-German Shepherd Dog Mix',),
#  ('Hovawart',),
#  ('Havanese-Yorkshire Terrier Mix',),
#  ('Havanese-Toy Fox Terrier Mix',),
#  ('Havanese-Shih Tzu Mix',),
#  ('Havanese-Poodle Mix',),
#  ('Havanese-Pekingese Mix',),
#  ('Havanese-Maltese Mix',),
#  ('Havanese-Lhasa Apso Mix',),
#  ('Havanese-Coton de Tulear Mix',),
#  ('Havanese-Chinese Crested Mix',),
#  ('Havanese-Cavalier King Charles Spaniel Mix',),
#  ('Havanese-Bichon Frise Mix',),
#  ('Havanese- Mix',),
#  ('Havanese',),
#  ('Harrier-Shiba Inu Mix',),
#  ('Harrier',),
#  ('Greyhound-Whippet Mix',),
#  ('Greyhound-Staffordshire Bull Terrier Mix',),
#  ('Greyhound-Scottish Deerhound Mix',),
#  ('Greyhound-Saluki Mix',),
#  ('Greyhound-Pointer Mix',),
#  ('Greyhound-Labrador Retriever Mix',),
#  ('Greyhound-Irish Wolfhound Mix',),
#  ('Greyhound-Golden Retriever Mix',),
#  ('Greyhound-Border Collie Mix',),
#  ('Greyhound-Bedlington Terrier Mix',),
#  ('Greyhound-Australian Shepherd Mix',),
#  ('Greyhound-American Pit Bull Terrier Mix',),
#  ('Greyhound-American Foxhound Mix',),
#  ('Greyhound',),
#  ('Greater Swiss Mountain Dog-Border Collie Mix',),
#  ('Greater Swiss Mountain Dog',),
#  ('Great Pyrenees-Welsh Springer Spaniel Mix',),
#  ('Great Pyrenees-Siberian Husky Mix',),
#  ('Great Pyrenees-Portuguese Water Dog Mix',),
#  ('Great Pyrenees-Labrador Retriever Mix',),
#  ('Great Pyrenees-Kuvasz Mix',),
#  ('Great Pyrenees-Golden Retriever Mix',),
#  ('Great Pyrenees-Chow Chow Mix',),
#  ('Great Pyrenees-Brussels Griffon Mix',),
#  ('Great Pyrenees-Border Collie Mix',),
#  ('Great Pyrenees-Bernese Mountain Dog Mix',),
#  ('Great Pyrenees-Australian Shepherd Mix',),
#  ('Great Pyrenees-Australian Cattle Dog Mix',),
#  ('Great Pyrenees',),
#  ('Great Dane-Siberian Husky Mix',),
#  ('Great Dane-Rottweiler Mix',),
#  ('Great Dane-Rhodesian Ridgeback Mix',),
#  ('Great Dane-Pointer Mix',),
#  ('Great Dane-Mastiff Mix',),
#  ('Great Dane-Labrador Retriever Mix',),
#  ('Great Dane-Irish Wolfhound Mix',),
#  ('Great Dane-Doberman Pinscher Mix',),
#  ('Great Dane-Bullmastiff Mix',),
#  ('Great Dane-Bulldog Mix',),
#  ('Great Dane-Boxer Mix',),
#  ('Great Dane-Boerboel Mix',),
#  ('Great Dane-American Staffordshire Terrier Mix',),
#  ('Great Dane-Alaskan Malamute Mix',),
#  ('Great Dane',),
#  ('Grand Basset Griffon Vendeen- Mix',),
#  ('Grand Basset Griffon Vendeen',),
#  ('Gordon Setter- Mix',),
#  ('Gordon Setter',),
#  ('Golden Retriever-Standard Schnauzer Mix',),
#  ('Golden Retriever-Standard Poodle Mix',),
#  ('Golden Retriever-St. Bernard Mix',),
#  ('Golden Retriever-Siberian Husky Mix',),
#  ('Golden Retriever-Redbone Coonhound Mix',),
#  ('Golden Retriever-Portuguese Podengo Mix',),
#  ('Golden Retriever-Poodle Mix',),
#  ('Golden Retriever-Polish Lowland Sheepdog Mix',),
#  ('Golden Retriever-Plott Mix',),
#  ('Golden Retriever-Pembroke Welsh Corgi Mix',),
#  ('Golden Retriever-Nova Scotia Duck Tolling Retriever Mix',),
#  ('Golden Retriever-Newfoundland Mix',),
#  ('Golden Retriever-Labrador Retriever Mix',),
#  ('Golden Retriever-Irish Wolfhound Mix',),
#  ('Golden Retriever-Irish Setter Mix',),
#  ('Golden Retriever-Great Pyrenees Mix',),
#  ('Golden Retriever-German Shepherd Dog Mix',),
#  ('Golden Retriever-English Cocker Spaniel Mix',),
#  ('Golden Retriever-Collie Mix',),
#  ('Golden Retriever-Cocker Spaniel Mix',),
#  ('Golden Retriever-Chow Chow Mix',),
#  ('Golden Retriever-Chinese Shar-Pei Mix',),
#  ('Golden Retriever-Cavalier King Charles Spaniel Mix',),
#  ('Golden Retriever-Cardigan Welsh Corgi Mix',),
#  ('Golden Retriever-Bullmastiff Mix',),
#  ('Golden Retriever-Brittany Mix',),
#  ('Golden Retriever-Border Collie Mix',),
#  ('Golden Retriever-Bernese Mountain Dog Mix',),
#  ('Golden Retriever-Belgian Malinois Mix',),
#  ('Golden Retriever-Beagle Mix',),
#  ('Golden Retriever-Basset Hound Mix',),
#  ('Golden Retriever-Australian Shepherd Mix',),
#  ('Golden Retriever-Airedale Terrier Mix',),
#  ('Golden Retriever- Mix',),
#  ('Golden Retriever',),
#  ('Golden Doodle',),
#  ('Glen of Imaal Terrier-Irish Terrier Mix',),
#  ('Glen of Imaal Terrier',),
#  ('Giant Schnauzer-Standard Poodle Mix',),
#  ('Giant Schnauzer-Poodle Mix',),
#  ('Giant Schnauzer-American Eskimo Dog Mix',),
#  ('Giant Schnauzer',),
#  ('German Wirehaired Pointer',),
#  ('German Spitz-Pomeranian Mix',),
#  ('German Spitz',),
#  ('German Shorthaired Pointer-Whippet Mix',),
#  ('German Shorthaired Pointer-Vizsla Mix',),
#  ('German Shorthaired Pointer-Rottweiler Mix',),
#  ('German Shorthaired Pointer-Pointer Mix',),
#  ('German Shorthaired Pointer-Newfoundland Mix',),
#  ('German Shorthaired Pointer-Labrador Retriever Mix',),
#  ('German Shorthaired Pointer-German Longhaired Pointer Mix',),
#  ('German Shorthaired Pointer-Catahoula Leopard Dog Mix',),
#  ('German Shorthaired Pointer-Boston Terrier Mix',),
#  ('German Shorthaired Pointer-American Pit Bull Terrier Mix',),
#  ('German Shorthaired Pointer- Mix',),
#  ('German Shorthaired Pointer',),
#  ('German Shepherd Dog-Whippet Mix',),
#  ('German Shepherd Dog-Treeing Walker Coonhound Mix',),
#  ('German Shepherd Dog-Staffordshire Bull Terrier Mix',),
#  ('German Shepherd Dog-Siberian Husky Mix',),
#  ('German Shepherd Dog-Shiba Inu Mix',),
#  ('German Shepherd Dog-Shetland Sheepdog Mix',),
#  ('German Shepherd Dog-Rottweiler Mix',),
#  ('German Shepherd Dog-Rhodesian Ridgeback Mix',),
#  ('German Shepherd Dog-Redbone Coonhound Mix',),
#  ('German Shepherd Dog-Pug Mix',),
#  ('German Shepherd Dog-Poodle Mix',),
#  ('German Shepherd Dog-Pembroke Welsh Corgi Mix',),
#  ('German Shepherd Dog-Nova Scotia Duck Tolling Retriever Mix',),
#  ('German Shepherd Dog-Norwegian Elkhound Mix',),
#  ('German Shepherd Dog-Mastiff Mix',),
#  ('German Shepherd Dog-Labrador Retriever Mix',),
#  ('German Shepherd Dog-Keeshond Mix',),
#  ('German Shepherd Dog-Irish Terrier Mix',),
#  ('German Shepherd Dog-Ibizan Hound Mix',),
#  ('German Shepherd Dog-Greyhound Mix',),
#  ('German Shepherd Dog-Great Pyrenees Mix',),
#  ('German Shepherd Dog-Great Dane Mix',),
#  ('German Shepherd Dog-Gordon Setter Mix',),
#  ('German Shepherd Dog-Golden Retriever Mix',),
#  ('German Shepherd Dog-Finnish Spitz Mix',),
#  ('German Shepherd Dog-English Setter Mix',),
#  ('German Shepherd Dog-Dutch Shepherd Mix',),
#  ('German Shepherd Dog-Doberman Pinscher Mix',),
#  ('German Shepherd Dog-Dachshund Mix',),
#  ('German Shepherd Dog-Collie Mix',),
#  ('German Shepherd Dog-Chow Chow Mix',),
#  ('German Shepherd Dog-Chinese Shar-Pei Mix',),
#  ('German Shepherd Dog-Central Asian Shepherd Dog Mix',),
#  ('German Shepherd Dog-Cardigan Welsh Corgi Mix',),
#  ('German Shepherd Dog-Cane Corso Mix',),
#  ('German Shepherd Dog-Bullmastiff Mix',),
#  ('German Shepherd Dog-Boxer Mix',),
#  ('German Shepherd Dog-Border Collie Mix',),
#  ('German Shepherd Dog-Bolognese Mix',),
#  ('German Shepherd Dog-Bluetick Coonhound Mix',),
#  ('German Shepherd Dog-Bloodhound Mix',),
#  ('German Shepherd Dog-Black and Tan Coonhound Mix',),
#  ('German Shepherd Dog-Bernese Mountain Dog Mix',),
#  ('German Shepherd Dog-Belgian Tervuren Mix',),
#  ('German Shepherd Dog-Belgian Sheepdog Mix',),
#  ('German Shepherd Dog-Belgian Malinois Mix',),
#  ('German Shepherd Dog-Bearded Collie Mix',),
#  ('German Shepherd Dog-Beagle Mix',),
#  ('German Shepherd Dog-Basset Hound Mix',),
#  ('German Shepherd Dog-Basenji Mix',),
#  ('German Shepherd Dog-Australian Shepherd Mix',),
#  ('German Shepherd Dog-Australian Kelpie Mix',),
#  ('German Shepherd Dog-Australian Cattle Dog Mix',),
#  ('German Shepherd Dog-American Staffordshire Terrier Mix',),
#  ('German Shepherd Dog-American Pit Bull Terrier Mix',),
#  ('German Shepherd Dog-American Eskimo Dog Mix',),
#  ('German Shepherd Dog-Alaskan Malamute Mix',),
#  ('German Shepherd Dog-Akita Mix',),
#  ('German Shepherd Dog- Mix',),
#  ('German Shepherd Dog',),
#  ('German Pinscher-Weimaraner Mix',),
#  ('German Pinscher',),
#  ...]

# %% [markdown]
# Combinar ORDER BY con LIMIT nos permite de una manera fácil de seleccionar los "10 primeros" y los "últimos 10" en una lista o columna. Por ejemplo: quereemos seleccionar los ID de 3 ID de usuarios que pasaron la mayor cantidad de tiempo en sus pruebas.

# %%
# %%sql
# SELECT DISTINCT user_guid, median_ITI_minutes
# FROM dogs
# ORDER BY median_ITI_minutes DESC
# LIMIT 3;
# Out:
#  * mysql://studentuser:***@localhost/dognitiondb
# 3 rows affected.
# [('ce7a74c8-7144-11e5-ba71-058fbc01cf0b', '9964.75'),
#  ('ce7b0686-7144-11e5-ba71-058fbc01cf0b', '9934.6000001'),
#  ('ce3c4a40-7144-11e5-ba71-058fbc01cf0b', '9912.3499999')]

# %% [markdown]
# También puede ordenar su salida en función de un campo derivado. Si quisiera que su intervalo entre pruebas se expresara en segundos en lugar de minutos, podría incorporar una columna derivada y un alias en su última consulta para obtener los 3 pares de perros y clientes que pasaron la mayor cantidad de tiempo promedio entre sus pruebas Dognition en segundos:

# %%
# %%sql
# SELECT DISTINCT user_guid, (median_ITI_minutes*60) AS median_ITI_sec
# FROM dogs
# ORDER BY median_ITI_sec DESC
# LIMIT 3;
# Out:
#  * mysql://studentuser:***@localhost/dognitiondb
# 3 rows affected.
# [('ce33102e-7144-11e5-ba71-058fbc01cf0b', 56242621.0002),
#  ('ce71fdde-7144-11e5-ba71-058fbc01cf0b', 28501473.0),
#  ('ce2462fe-7144-11e5-ba71-058fbc01cf0b', 23877894.0)]

# %% [markdown]
# Si desea seleccionar todos los ID de usuario distintos de los clientes en los Estados Unidos (abreviado "US") y ordenarlos según los estados en los que viven en orden alfabético primero y el tipo de membresía en segundo lugar, podría consultar. Como hay valores nulos en las columnas estado y tipo de membresía, escribimos la consulta para excluirlos del resultado:

# %%
# %%sql
# SELECT DISTINCT user_guid, state, membership_type
# FROM users
# WHERE country="US" AND state IS NOT NULL and membership_type IS NOT NULL
# ORDER BY state ASC, membership_type ASC
# LIMIT 6;
# Out:
#  * mysql://studentuser:***@localhost/dognitiondb
# 6 rows affected.
# [('ce138312-7144-11e5-ba71-058fbc01cf0b', 'AE', 1),
#  ('ce7587ba-7144-11e5-ba71-058fbc01cf0b', 'AE', 1),
#  ('ce76f528-7144-11e5-ba71-058fbc01cf0b', 'AE', 1),
#  ('ce221dbe-7144-11e5-ba71-058fbc01cf0b', 'AE', 2),
#  ('ce70836e-7144-11e5-ba71-058fbc01cf0b', 'AE', 2),
#  ('ce969298-7144-11e5-ba71-058fbc01cf0b', 'AE', 3)]

# %% [markdown]
# Hay dos formas de exportar los resultados de su consulta utilizando nuestra interfaz Jupyter. Con un copy and paste, aunque esta estrategia es muy simple, solo funciona si su salida tiene un tamaño muy limitado. También es posible, pedirle a MySQL, colocar los resultados de una consulta en una variable como un lugar de almacenamiento temporal y luego usar el código de Python para formatear los datos en la variable como un archivo CSV que se puede descargar. De esta forma, todos los resultados de una consulta se guardarán en la variable, no solo las primeras 1000 filas como se muestra en Jupyter, incluso si hemos configurado Jupyter para mostrar solo 1000 filas de la salida. El enlace para descargar, se ve en la línea de salida, también,  puede acceder al archivo desde la página de inicio de Jupyter, donde puede realizar cualquier acción como un notebook más.
# Por ejemplo, queremos exportar una lista con las razas registradas en la base de datos, ordenadas de forma descendente.

# %%
breed_list = %sql SELECT DISTINCT breed FROM dogs ORDER BY breed;

# %%
breed_list.csv('breed_list.csv')

# %% [markdown]
# Como se puede observar en el archivo, los datos de la columna raza necesitan una limpieza. Usamos la función REPLACE para eliminar los guiones de razas, pero también se eliminarán los guiones intermedios como el de French Bulldog-Boston. De manera que si queremos mantener estos tipos de guíones, podemos usar la función TRIM.

# %%
SELECT DISTINCT breed,
REPLACE(breed,'-','') AS breed_fixed
FROM dogs
ORDER BY breed_fixed;

# %%
# %%sql
# SELECT DISTINCT breed, TRIM(LEADING '-' FROM breed) AS breed_fixed
# FROM dogs
# ORDER BY breed_fixed;
